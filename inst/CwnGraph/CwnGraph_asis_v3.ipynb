# %%
# %load_ext autoreload
# %autoreload 2
import pickle
from CwnGraph import CwnBase, CwnAnnotator
from CwnGraph import CwnRelationType
# 似乎可以不用 run 
cwn = CwnBase.install_cwn("data/cwn_graph.pyobj")
cwn = CwnBase()
from pprint import pprint

print("CwnGraph 資料查詢小幫手")
print("="*60)

switch = True
while switch == True:
    print("::: 小幫手功能說明 :::","--查詢詞義 >>>>>> 請輸入 a ","--查詢詞義與例句 >>>>>> 請輸入 b ", "--結束小幫手 >>>>>> 請輸入 1 ", sep="\n", end="\n\n\n")
    item = input('<功能選擇> 請輸入英文字母：')
    if item == "a":
        findsenses = True
        while findsenses == True:
            lookingsense = input('[a] 查詢詞義 >> 請輸入欲查詢的詞(跳出請輸入 2 )：')
            if lookingsense not in ["1", "2", "b"]:
                center = "^"+lookingsense+"$"
                lemmas = cwn.find_lemma(center)
                senses = cwn.find_senses(lemma=center)
                print("="*20,'\n','[[[查詢結果]]]','\n')
                print("所查詞彙:",lookingsense, "\n", "詞彙(lemma)數量:", len(lemmas), "\n", "詞義(sense)數量:",len(senses), "\n")
                for lemm in lemmas:
                    lemsense = lemm.senses
                    print(lemm)
                    if len(lemsense) > 0:
                        for i in range(len(lemsense)):
                            pos = lemsense[i].data()["pos"]
                        #examples = lemsense[i].examples[0]
                            print(" ", "[詞性]", pos, " ", lemsense[i])
                print("="*30)
                    
            elif lookingsense == "2":
                print("\n",'跳出詞義查詢～～～',end="\n\n")
                print("="*30)
                findsenses = False
            
            elif lookingsense == "1":
                print("\n", '再會～～～小幫手退場囉～～～',end="\n\n")
                findsenses = False
                switch = False
                
            elif lookingsense == "b":
                print("\n", '跳至查詢詞義與例句～～～',end="\n\n")
                print("="*30)
                findsenses = False 
                item = "b"
                
    if item == "b":    
        findall = True
        while findall == True:
            name = input('[b] 查詢詞義與例句 >> 請輸入欲查詢的詞(跳出請輸入 2 )：')
            seed = "^"+name+"$"
            lemman= len(cwn.find_senses(lemma=seed))
            result = {x: x.all_examples() for x in cwn.find_senses(seed)}
            
            if name not in ["1", "2", "a"]:
                print("="*20,'\n','[[[查詢結果]]]',"\n\n", "「", name, "」的詞義數量：",lemman,"\n------")
                for k, v in result.items():
                    spos = k.data()["pos"]
                    print("詞性:", spos,"  ", k,"\n", "\t::例句::", "\n\t", '\n\t'.join(v),"\n","------","\n")
                
                print("="*30)

            elif name == "2":
                print("\n", "跳出詞義與例句查詢～～～",end="\n\n")
                print("="*30)
                findall = False
                
            elif name == "1":
                print("\n", '再會～～～小幫手退場囉～～～',end="\n\n")
                findall = False
                switch = False
                
            elif name == "a":
                print("\n", '跳至查詢詞義～～～',end="\n\n")
                print("="*30)
                findall = False
                item = "a" #不知如何跳回去 [a] 查詢詞義＠＠
                findsenses = True
                
               
    if item == "1":
        print("\n", '再會～～～小幫手退場囉～～～')
        switch = False
# Out:
# CWN data installed
# CwnGraph 資料查詢小幫手
# ============================================================
# ::: 小幫手功能說明 :::
# --查詢詞義 >>>>>> 請輸入 a
# --查詢詞義與例句 >>>>>> 請輸入 b
# --結束小幫手 >>>>>> 請輸入 1
# <功能選擇> 請輸入英文字母： b
# [b] 查詢詞義與例句 >> 請輸入欲查詢的詞(跳出請輸入 2 )： 中
# ====================
#  [[[查詢結果]]]
#
#  「 中 」的詞義數量： 36
# ------
# 詞性: Ncd    <CwnSense[04004601](中): 空間範圍與各端點距離大約相等的位置。>
#  	::例句::
# 	 三棒後藤首先擊出一支<中>外野方向二壘安打。
# 	中山王嫦娥在門前十二碼接應右翼底線吊<中>，直射入網。
# 	青年握著吐信的蛇，面對人群走了一圈。青年在圈<中>立定，開口說道。
#  ------
#
# 詞性: Nc,Ncd    <CwnSense[04004602](中): 空間範圍內包含參考點的區域。>
#  	::例句::
# 	 看齊時中央伍為準海軍在左空軍在右好對準我向<中>看齊。
# 	台灣地區分北、<中>、南、東部四區域，初期缺少通盤的規劃。
# 	德國境內分為４個地理區，分別是北德平原、<中>德高地、南德高地與巴伐利亞阿爾卑斯山區。
# 	昨天起將全縣十三個鄉鎮衛生所，分為北、<中>、南三組，每一組輪設一名召集人。
# 	看齊時中央伍為準海軍在左空軍在右好對準我向<中>看齊。
# 	台灣地區分北、<中>、南、東部四區域，初期缺少通盤的規劃。
# 	德國境內分為４個地理區，分別是北德平原、<中>德高地、南德高地與巴伐利亞阿爾卑斯山區。
# 	昨天起將全縣十三個鄉鎮衛生所，分為北、<中>、南三組，每一組輪設一名召集人。
#  ------
#
# 詞性: Ncd    <CwnSense[04004603](中): 在前述對象所包含的空間範圍。>
#  	::例句::
# 	 媽媽先教我漂浮、水<中>站立、換氣，再加上踢腳、蛙手。
# 	目前櫻花鉤吻鮭已能在雪霸國家公園<中>的七家灣溪悠游自在的生活。
# 	您多多保重吧！他一口氣把杯<中>酒喝乾了，眼淚卻忍不住流下來了。
# 	江戶時期，德川家康的子孫在日光的山<中>建造了一座寺廟。
# 	行館前方有一寬大廣場，場<中>設有圓形花圃，四周種滿青綠的樹木。
#  ------
#
# 詞性: Ng    <CwnSense[04004604](中): 在前述的時間範圍內。>
#  	::例句::
# 	 貂是天生的游泳好手，一生<中>有大半時光生活在水中。
# 	多少韻事，多少風情，在這一剎那<中>點燃了火花，漸漸增長，不斷地蔓延。
# 	任尼公司宣稱在１９９１年<中>即已提出和宏碁相同的電腦升級技術和觀念。
# 	台灣地區十五歲以上人口，一天二十四小時<中>，有十點四五小時是用在睡眠。
#  ------
#
# 詞性: Ncd,Ng    <CwnSense[04004605](中): 在前述的機構或領域範圍。>
#  	::例句::
# 	 這項構想將在即將舉行的臨時大會<中>提案。
# 	據說「紅樓夢」<中>之「大觀園」即仿自拙政園。
# 	當年皇帝把玩手<中>的古玉，那能料到今天在陳列櫃公開展示？
# 	生長在東方文化<中>的人，對於關係的互動往往特別敏銳。
# 	在研究史學的人、事、史、地、物五種元素<中>，老契約屬於物的一種。
# 	這項構想將在即將舉行的臨時大會<中>提案。
# 	據說「紅樓夢」<中>之「大觀園」即仿自拙政園。
# 	當年皇帝把玩手<中>的古玉，那能料到今天在陳列櫃公開展示？
# 	生長在東方文化<中>的人，對於關係的互動往往特別敏銳。
# 	在研究史學的人、事、史、地、物五種元素<中>，老契約屬於物的一種。
#  ------
#
# 詞性: A    <CwnSense[04004606](中): 空間範圍分三部份時，不屬於兩端點的高度。>
#  	::例句::
# 	 可以看出來，是從這個，嗯，副熱帶地區呢，慢慢慢慢，<中>緯度地區，嗯，移動。
# 	攜有九百公斤重的彈頭，並配備有導引系統，使之能由<中>、低空準確命中目標。
#  ------
#
# 詞性: Ng    <CwnSense[04004607](中): 時間範圍分三階段時，不屬於兩端點的時段。>
#  	::例句::
# 	 舊金山的中國城大約興起於19世紀<中>。
# 	目前已經推出試印本，正式發行的版本將在十一月底至十二月<中>出版。
# 	大盤應能持續選後漲勢而緩步攻堅，在農曆春節封關日（二月<中>）附近出現高點。
#  ------
#
# 詞性: Ncd,A    <CwnSense[04004608](中): 事物分成三部份時，不在兩端的部份。>
#  	::例句::
# 	 本段資料來源：台灣總督府警察沿革志第二編，<中>卷，一二八至一三一頁。
# 	建築物依基地形狀略做轉彎，開口朝內而呈ㄑ字形，可略等分為左，<中>，右三段。
# 	大陸地殼也可分為三層：上層為沈積岩和山脈，<中>層為花崗岩質的變質岩，下層為角閃岩。
# 	本段資料來源：台灣總督府警察沿革志第二編，<中>卷，一二八至一三一頁。
# 	建築物依基地形狀略做轉彎，開口朝內而呈ㄑ字形，可略等分為左，<中>，右三段。
# 	大陸地殼也可分為三層：上層為沈積岩和山脈，<中>層為花崗岩質的變質岩，下層為角閃岩。
#  ------
#
# 詞性: Ncd    <CwnSense[04004609](中): 順序不在兩端的部份。>
#  	::例句::
# 	 <中>右為亞奧主席阿罕默德，他身旁的是海峽兩岸奧會主席。
# 	八輕計劃邀集大洋塑膠、中美和等十八家<中>、下游業者參與。
# 	這三種文類分別是：論述類、對話類，及詩歌散文類。前者主要是客觀敘事性的，後者則為主觀抒情性，<中>者則性質介於二者之間，而偏重人與人的溝通交流。
#  ------
#
# 詞性: Na,A,VH    <CwnSense[04004610](中): 階段不在兩端的部份。>
#  	::例句::
# 	 目前園中設有大、<中>、小各一班，每班園生各三十名。
# 	網際網路用戶人數的推廣，要靠e-mail到<中>、小學計畫。
# 	每年從各個學校國劇科組畢業的學生不計其數，但在老、<中>輩藝人的光芒遮蓋之下，新人們頂多上台扮演龍套配角。
# 	國小客家語教學觀摩會昨天在國語實小舉行，分組進行高、<中>、低等三個年級的教學演示。
# 	目前園中設有大、<中>、小各一班，每班園生各三十名。
# 	網際網路用戶人數的推廣，要靠e-mail到<中>、小學計畫。
# 	每年從各個學校國劇科組畢業的學生不計其數，但在老、<中>輩藝人的光芒遮蓋之下，新人們頂多上台扮演龍套配角。
# 	國小客家語教學觀摩會昨天在國語實小舉行，分組進行高、<中>、低等三個年級的教學演示。
# 	目前園中設有大、<中>、小各一班，每班園生各三十名。
# 	網際網路用戶人數的推廣，要靠e-mail到<中>、小學計畫。
# 	每年從各個學校國劇科組畢業的學生不計其數，但在老、<中>輩藝人的光芒遮蓋之下，新人們頂多上台扮演龍套配角。
# 	國小客家語教學觀摩會昨天在國語實小舉行，分組進行高、<中>、低等三個年級的教學演示。
#  ------
#
# 詞性: A    <CwnSense[04004611](中): 形容階級架構不在兩端的。>
#  	::例句::
# 	 在這裡處處可見<中>高階層人士們的海邊小屋和高級渡假別墅。
# 	低、中低、<中>階級份子的財產都縮水了，可是整個國家是賺錢的呀。
#  ------
#
# 詞性: Na,Nes    <CwnSense[04004612](中): 等級不在兩端的部份。>
#  	::例句::
# 	 「神農本草經」中將藥品分為上、<中>、下三品。
# 	父親是科舉<中>人，要看報條，丈人是商人，要看契據。
# 	而上肉銷給日本，<中>、下肉賣給蘇聯，一整隻豬都有去處也算不錯。
# 	「神農本草經」中將藥品分為上、<中>、下三品。
# 	父親是科舉<中>人，要看報條，丈人是商人，要看契據。
# 	而上肉銷給日本，<中>、下肉賣給蘇聯，一整隻豬都有去處也算不錯。
#  ------
#
# 詞性: A    <CwnSense[04004613](中): 形容接近標準或平均的距離長度的。>
#  	::例句::
# 	 十八日（初四）是年假結束日，<中>、長途旅客最多。
# 	這個球員是左撇子，速度不快，但在<中>距離投擦板球，命中率五成三一。
#  ------
#
# 詞性: Na,A,Nd    <CwnSense[04004614](中): 接近標準或平均的時段長度。>
#  	::例句::
# 	 前任李登輝市長所訂的<中>、長程計畫，只是一個大概、原則性的目標。
# 	國內景氣面不再惡化的利多，<中>長期走勢可望修正為短空對<中>長多。
# 	教育部擬定了短、<中>、長期之目標，初期目標（西元１９９８年以前）為完成。
# 	前任李登輝市長所訂的<中>、長程計畫，只是一個大概、原則性的目標。
# 	國內景氣面不再惡化的利多，<中>長期走勢可望修正為短空對<中>長多。
# 	教育部擬定了短、<中>、長期之目標，初期目標（西元１９９８年以前）為完成。
# 	前任李登輝市長所訂的<中>、長程計畫，只是一個大概、原則性的目標。
# 	國內景氣面不再惡化的利多，<中>長期走勢可望修正為短空對<中>長多。
# 	教育部擬定了短、<中>、長期之目標，初期目標（西元１９９８年以前）為完成。
#  ------
#
# 詞性: Na,A    <CwnSense[04004615](中): 接近標準或平均的規模大小。>
#  	::例句::
# 	 她覺得第一次約會不好意思，於是點了<中>碗。
# 	錢復積極協調各部會，陳履安不停走訪<中>、小企業。
# 	每公頃居住密度為三百三十三人左右，屬於<中>密度開發。
# 	後來也逐漸發展出俱備娛樂、社交、保育等各項功能的大、<中>、小鄰里公園。
# 	她覺得第一次約會不好意思，於是點了<中>碗。
# 	錢復積極協調各部會，陳履安不停走訪<中>、小企業。
# 	每公頃居住密度為三百三十三人左右，屬於<中>密度開發。
# 	後來也逐漸發展出俱備娛樂、社交、保育等各項功能的大、<中>、小鄰里公園。
#  ------
#
# 詞性: Na,A    <CwnSense[04004616](中): 形容功能接近標準或平均的。>
#  	::例句::
# 	 乾麵辣味分四等，有輕辣、<中>辣、重辣及超級辣。
# 	明年有關<中>、低品級網球拍之生產，將率先移至泰國。
# 	圖形複雜度過高使得受試者建構立體模型的可能性降低，故以具<中>和低複雜度之圖形再度檢驗線索效應。
# 	乾麵辣味分四等，有輕辣、<中>辣、重辣及超級辣。
# 	明年有關<中>、低品級網球拍之生產，將率先移至泰國。
# 	圖形複雜度過高使得受試者建構立體模型的可能性降低，故以具<中>和低複雜度之圖形再度檢驗線索效應。
#  ------
#
# 詞性: Na,A    <CwnSense[04004617](中): 年齡在四十到六十歲間。>
#  	::例句::
# 	 她共計前後換過老、<中>、青三個年紀不等的保母。
# 	人一生的老、<中>、少都有關卡，這來自於我們的年齡和人生階段。
# 	由於點名的人大都是<中>老年的女性教職員，所以學生都稱他們為「點名媽媽」。
# 	她共計前後換過老、<中>、青三個年紀不等的保母。
# 	人一生的老、<中>、少都有關卡，這來自於我們的年齡和人生階段。
# 	由於點名的人大都是<中>老年的女性教職員，所以學生都稱他們為「點名媽媽」。
#  ------
#
# 詞性: Ng    <CwnSense[04004618](中): 在事件的過程中。>
#  	::例句::
# 	 查訪<中>覺得黃某神態怪異，追問下黃某坦承吸食安非他命。
# 	其實電腦已經在不知不覺<中>，為我們的家居生活提供便利。
# 	魁北克的獨立運動雖然在這次公投<中>再次遭到挫敗，但法裔與英裔之間的長期恩怨卻不會就此結束。
# 	在全場六十分鐘的賽程<中>，巨人隊取得控球時間達四十三分鐘。
#  ------
#
# 詞性: Di    <CwnSense[04004619](中): 時態標記。表持續狀態。>
#  	::例句::
# 	 聯外道路部分路段路基坍方、落石，施工<中>。
# 	李大木畫作現正於清藝術中心展出<中>，展期至廿二日。
# 	印尼、中國大陸都是發展<中>國家，在經濟上都要加倍努力。
#  ------
#
# 詞性: Na,Nc    <CwnSense[04004620](中): 人心。>
#  	::例句::
# 	 就人的本性而言，「直」是最快樂的，也就是「誠」。誠於<中>形於外，內在有什麼就直接表達出來。
# 	就人的本性而言，「直」是最快樂的，也就是「誠」。誠於<中>形於外，內在有什麼就直接表達出來。
#  ------
#
# 詞性: Na    <CwnSense[04004621](中): 麻將中的牌面，為三種箭牌之一。>
#  	::例句::
# 	 遊戲中的方塊由麻將中的「東南西北<中>發」這六色方塊來構成。
# 	今日贏錢局，排排對子招。 三元（<中>發白）兼四喜（東南西北）。
# 	紙牌開始共有60張，分為文錢、索子、萬貫三種花色，其三色都是一至九各兩張，另有么頭三色（即麻將牌中的<中>、發、白）各兩張。
#  ------
#
# 詞性: Na    <CwnSense[04004622](中): 在特定領域中，累積足夠經歷正在承擔主要工作的一輩。>
#  	::例句::
# 	 由台灣中華電視公司演藝人員組成的華夏訪問團，成員包括台灣演藝界老、<中>、青的知名人物。
# 	以往對台灣攝影作品印象不深的他，昨天看到結合老、<中>、青三代攝影家的作品集後，相當吃驚，並十分稱許。
# 	主辦單位還特別邀請國際知名的日本老、<中>、青三代撞球高手-木村義一、內山哲夫、白岩篤，和世界撞球排名第一的國手趙豐邦及國內職業新秀楊清順展開四場精彩的「國際撞球明星表演賽」。
#  ------
#
# 詞性: VJ    <CwnSense[05007601](中): 從施力來源使投擲物經過運動路徑到達目標。>
#  	::例句::
# 	 而柯爾曼則出手十五次<中>六，共攻下十三分。
# 	哥哥到靶場打靶，一發即<中>，哥哥樂得笑哈哈。
# 	瓦耳拉齊大喝一聲，左拳揮出，正<中>蘇普鼻樑。
#  ------
#
# 詞性: VJ    <CwnSense[05007602](中): 因疾病或毒素而影響身體機能。>
#  	::例句::
# 	 我是後心的穴道上<中>了...<中>了一枚毒針。
# 	大家都<中>那個毒，不要讓孩子輸在起跑點上。話是沒錯啦！
# 	血中鈣的濃度容易飆過頭而引起高血鈣，使全身<中>了鈣太多的毒。
#  ------
#
# 詞性: VJ    <CwnSense[05007603](中): 因他人的惡意設計而受到負面影響。>
#  	::例句::
# 	 在當夜率兵劫營，不料卻<中>了張飛的伏兵之計，大敗而逃。
# 	見那馬周身沒半點傷痕，口鼻亦不流血，卻不知如何，竟是<中>了魔法而死。
# 	野狼使出擒爪功，奶奶也不甘示弱的使出旋風繡腿，結果大野狼<中>了奶奶的招數。
#  ------
#
# 詞性: VJ    <CwnSense[05007604](中): 因幸運而獲得獎勵。>
#  	::例句::
# 	 現在看來，鮑小姐那位未婚夫一定會<中>航空獎券頭獎。
# 	我們班好戲也快開鑼了，每個同學都像<中>了彩券一樣，興奮異常。
# 	與這名顧客對賭，下注賭金從一千元至三千元不等，結果數次未<中>。
#  ------
#
# 詞性: VJ    <CwnSense[05007605](中): 接近或配合後述對象的預期。>
#  	::例句::
# 	 而且他講一句話我覺得，非常<中>我的胃口。
#  ------
#
# 詞性: VJ    <CwnSense[05007606](中): 在競爭過程中達成目標。>
#  	::例句::
# 	 光緒十四年（1888年），渠源禎之子渠本翹<中>進士。
# 	1863年，中國承包商魏榮昌<中>標承建法租界公董局大樓。
# 	初審符合規定者，另擇期公開辦理順位抽籤，再依<中>籤順位建立等候名冊。
#  ------
#
# 詞性: Nc    <CwnSense[08011201](中): 國名，位於亞洲東部的國家，東瀕太平洋，北臨俄國，是世界上人口最多的國家。>
#  	::例句::
# 	 恭親王和文祥為自強的事業打下了基礎，後繼的官員，一直到一八九四年<中>日戰爭的時候，也都朝這個方向去做。
# 	林則徐大舉禁煙，得到的回應是一八四九年的「鴉片戰爭」；也就是英文書中所謂的「一連串小衝突導致的第一次英<中>戰爭」。
# 	由於<中>日之間，咫尺相鄰，因之漢族大量移居日本後，對日本文化的開啟、國家觀念的形成，以及政治、經濟的發展貢獻影響最大。
# 	他公開宣稱：現在主張一台一<中>，把台灣放在前面。
# 	金磚四國經濟表現凌厲，其中以<中>印最獲投資者青睞，短期有望繼續被看高一線。
# 	黃華外長與園田直外相在簽字長桌前並排而坐，福田糾夫首相和鄧小平坐在他們身旁，<中>日兩國官員分列兩旁。
#  ------
#
# 詞性: Nb    <CwnSense[08011202](中): 治理中國的政府。>
#  	::例句::
# 	 光緒21年，<中>日簽訂馬關條約，清廷割讓台灣。
# 	此後清政府和緬甸一直沒有建立外交關係，湄公河上流的小國要同時向<中>、緬兩國朝貢。
# 	因應大躍進及<中>蘇交惡的影響，聶榮臻採取務實及獨立自主的發展方針。
# 	<中>共建議<中>日雙方盡快就擱置主權、共同開發釣魚台海域資源、開放釣魚台海域漁業資源等問題，進行磋商。
# 	齊懷遠強調，<中>共的上述要求和建議，是從維護<中>日友好關係大局，維護亞太地區和平與穩定的戰略高度出發。
#  ------
#
# 詞性: Nc    <CwnSense[08011203](中): 位於臺灣島的國家，建立於西元1912年的民主共和國，轄區包含臺灣、澎湖、金門、馬祖。>
#  	::例句::
# 	 時至1972年，隨著日共建交，<中>日航線正式斷航。
# 	民國二十年，九一八事變，第二年東北變色，<中>日戰火一觸即發。
# 	江丙坤指出，<中>蘇間貿易，由於今年三月我國開放蘇聯之直接貿易而顯著增加。
#  ------
#
# 詞性: Nb    <CwnSense[08011204](中): 治理中華民國的政府。>
#  	::例句::
# 	 民國六十九年<中>美斷交，全省房地產界陷入黑暗期。
# 	華航留在沙國，除安定駐外僑民人心外，並可保持<中>沙雙方的實質關係。
# 	外交上退出聯合國、<中>日斷交的打擊，使得海外留學生開始詩人現聲喚醒遺落的詩情。
#  ------
#
# 詞性: Na    <CwnSense[08011205](中): 中華民族的文化。>
#  	::例句::
# 	 五歲小女孩娟娟，自小即小便失禁，家人帶她看過不少<中>、西醫，但一直無法改善。
# 	新工作坊成立了，包含藝術創作(西畫、<中>畫、混合媒材等)、藝術治療、相關研究等。
# 	走過一百多年的慌亂與自卑，我們早該擺脫「<中>學為體，西學為用」或「全盤西化」的爭議。
#  ------
#
# 詞性: Na    <CwnSense[08011206](中): 中華民族的主要通用語文，為中國大陸、臺灣、新加坡的官方語言。>
#  	::例句::
# 	 美國佛教會負責人沈家楨在新竹成立駐臺譯經院，招考<中>譯英的人才。
# 	將來的目標是每一個特展都有光碟出版品，而每一張光碟都有<中>日英法義德西語七種版本。
# 	精心規劃的機上視聽娛樂，內容包羅萬象，包括8個音樂頻道、最新影片欣賞、時事新聞報導等，並備有30多種<中>、英、日文報刊。
#  ------
#
# 詞性: Na    <CwnSense[08011207](中): 大學中教授中文知識的教學研究單位。中文系所的簡省。>
#  	::例句::
# 	 作者在大學修讀<中>日兩系，畢業後開始了寫小說的念頭。
# 	第十七屆中興湖文學獎徵文比賽第一名：吟遊詩人，張至廷，進修部<中>三乙。
#  ------
#
# 詞性: Nc    <CwnSense[08011301](中): 臺灣地名，位於臺灣中部，介於苗栗縣、彰化縣之間的地區。>
#  	::例句::
# 	 全球人力資本論壇北<中>高下月開講。
# 	在地理上烏日坐落台中大都會區內，位置恰為<中>、彰、投四縣市中心點。
# 	本單位曾承辦活動96年度<中>彰投雲區國立暨臺灣省私立職業學校一般科目教師研習。
#  ------
#
# ==============================
# [b] 查詢詞義與例句 >> 請輸入欲查詢的詞(跳出請輸入 2 )： 2
#  跳出詞義與例句查詢～～～
#
# ==============================
# ::: 小幫手功能說明 :::
# --查詢詞義 >>>>>> 請輸入 a
# --查詢詞義與例句 >>>>>> 請輸入 b
# --結束小幫手 >>>>>> 請輸入 1
# <功能選擇> 請輸入英文字母： a
# [a] 查詢詞義 >> 請輸入欲查詢的詞(跳出請輸入 2 )： 中
# ====================
#  [[[查詢結果]]]
#
# 所查詞彙: 中
#  詞彙(lemma)數量: 4
#  詞義(sense)數量: 36
#
# <CwnLemma: 中_2>
#   [詞性] Nc   <CwnSense[08011201](中): 國名，位於亞洲東部的國家，東瀕太平洋，北臨俄國，是世界上人口最多的國家。>
#   [詞性] Nb   <CwnSense[08011202](中): 治理中國的政府。>
#   [詞性] Nc   <CwnSense[08011203](中): 位於臺灣島的國家，建立於西元1912年的民主共和國，轄區包含臺灣、澎湖、金門、馬祖。>
#   [詞性] Nb   <CwnSense[08011204](中): 治理中華民國的政府。>
#   [詞性] Na   <CwnSense[08011205](中): 中華民族的文化。>
#   [詞性] Na   <CwnSense[08011206](中): 中華民族的主要通用語文，為中國大陸、臺灣、新加坡的官方語言。>
#   [詞性] Na   <CwnSense[08011207](中): 大學中教授中文知識的教學研究單位。中文系所的簡省。>
# <CwnLemma: 中_3>
#   [詞性] Nc   <CwnSense[08011301](中): 臺灣地名，位於臺灣中部，介於苗栗縣、彰化縣之間的地區。>
# <CwnLemma: 中_1>
#   [詞性] Ncd   <CwnSense[04004601](中): 空間範圍與各端點距離大約相等的位置。>
#   [詞性] Nc,Ncd   <CwnSense[04004602](中): 空間範圍內包含參考點的區域。>
#   [詞性] Ncd   <CwnSense[04004603](中): 在前述對象所包含的空間範圍。>
#   [詞性] Ng   <CwnSense[04004604](中): 在前述的時間範圍內。>
#   [詞性] Ncd,Ng   <CwnSense[04004605](中): 在前述的機構或領域範圍。>
#   [詞性] A   <CwnSense[04004606](中): 空間範圍分三部份時，不屬於兩端點的高度。>
#   [詞性] Ng   <CwnSense[04004607](中): 時間範圍分三階段時，不屬於兩端點的時段。>
#   [詞性] Ncd,A   <CwnSense[04004608](中): 事物分成三部份時，不在兩端的部份。>
#   [詞性] Ncd   <CwnSense[04004609](中): 順序不在兩端的部份。>
#   [詞性] Na,A,VH   <CwnSense[04004610](中): 階段不在兩端的部份。>
#   [詞性] A   <CwnSense[04004611](中): 形容階級架構不在兩端的。>
#   [詞性] Na,Nes   <CwnSense[04004612](中): 等級不在兩端的部份。>
#   [詞性] A   <CwnSense[04004613](中): 形容接近標準或平均的距離長度的。>
#   [詞性] Na,A,Nd   <CwnSense[04004614](中): 接近標準或平均的時段長度。>
#   [詞性] Na,A   <CwnSense[04004615](中): 接近標準或平均的規模大小。>
#   [詞性] Na,A   <CwnSense[04004616](中): 形容功能接近標準或平均的。>
#   [詞性] Na,A   <CwnSense[04004617](中): 年齡在四十到六十歲間。>
#   [詞性] Ng   <CwnSense[04004618](中): 在事件的過程中。>
#   [詞性] Di   <CwnSense[04004619](中): 時態標記。表持續狀態。>
#   [詞性] Na,Nc   <CwnSense[04004620](中): 人心。>
#   [詞性] Na   <CwnSense[04004621](中): 麻將中的牌面，為三種箭牌之一。>
#   [詞性] Na   <CwnSense[04004622](中): 在特定領域中，累積足夠經歷正在承擔主要工作的一輩。>
# <CwnLemma: 中_4>
#   [詞性] VJ   <CwnSense[05007601](中): 從施力來源使投擲物經過運動路徑到達目標。>
#   [詞性] VJ   <CwnSense[05007602](中): 因疾病或毒素而影響身體機能。>
#   [詞性] VJ   <CwnSense[05007603](中): 因他人的惡意設計而受到負面影響。>
#   [詞性] VJ   <CwnSense[05007604](中): 因幸運而獲得獎勵。>
#   [詞性] VJ   <CwnSense[05007605](中): 接近或配合後述對象的預期。>
#   [詞性] VJ   <CwnSense[05007606](中): 在競爭過程中達成目標。>
# ==============================
# [a] 查詢詞義 >> 請輸入欲查詢的詞(跳出請輸入 2 )： 分
# ====================
#  [[[查詢結果]]]
#
# 所查詞彙: 分
#  詞彙(lemma)數量: 4
#  詞義(sense)數量: 29
#
# <CwnLemma: 分_4>
#   [詞性] Na   <CwnSense[04108101](分): 在事件中發生作用的人際關係。>
#   [詞性] Na   <CwnSense[04108102](分): 無法自己選擇的角色。>
#   [詞性] Na   <CwnSense[04108103](分): 人的社會地位。>
#   [詞性] Na   <CwnSense[04108104](分): 在分配的事物中所取得的一分。>
#   [詞性] Nf   <CwnSense[04108105](分): 計算可分配的成套具體事物的單位。>
#   [詞性] Nf   <CwnSense[04108106](分): 計算可經由轉移後取得所有權的事物的單位。>
#   [詞性] Nf   <CwnSense[04108107](分): 計算文件、出版品的單位。>
#   [詞性] Nf   <CwnSense[04108108](分): 計算視為整體的抽象事物。>
# <CwnLemma: 分_2>
#   [詞性] VC   <CwnSense[04146401](分): 特定對象分開。>
#   [詞性] VC   <CwnSense[04146402](分): 結束原有的關係。>
#   [詞性] VC   <CwnSense[04146403](分): 將整體事物區隔成幾部份。>
#   [詞性] Nom,VC   <CwnSense[04146404](分): 區別兩個以上特定對象之間的不同。>
#   [詞性] VC   <CwnSense[04146405](分): 依特性做分類。>
#   [詞性] VC,VD   <CwnSense[04146406](分): 將事物分享或分配給人。>
#   [詞性] D   <CwnSense[04146408](分): 表分別。>
#   [詞性] VC   <CwnSense[04146409](分): 比喻一起承受他人的負面情緒。>
#   [詞性] A   <CwnSense[04146410](分): 形容由總機構或整體中分出來的。>
#   [詞性] VC   <CwnSense[04146407](分): 在分配的事務中取得一份。>
# <CwnLemma: 分_3>
#   [詞性] Na   <CwnSense[05007101](分): 用於紀錄成績或競賽結果的數目。>
#   [詞性] Nf   <CwnSense[05007102](分): 計算分數的單位。>
# <CwnLemma: 分_1>
#   [詞性] Na   <CwnSense[05007201](分): 時間單位，一分鐘為一小時的六十分之一。>
#   [詞性] Nf   <CwnSense[05007202](分): 計算時間的單位，一分鐘為一小時的六十分之一。>
#   [詞性] Nf   <CwnSense[05007203](分): 計算土地面積的單位，市制或台制，一分為一甲的十分之一。>
#   [詞性] Nf   <CwnSense[05007204](分): 計算貨幣的單位，一分為一元的百分之一。>
#   [詞性] Nf   <CwnSense[05007205](分): 計算利率的單位，一分為本金的十分之一。>
#   [詞性] Nf   <CwnSense[05007206](分): 計算重量的單位，市制或台制，一分為一兩的百分之一。>
#   [詞性] Nf   <CwnSense[05007207](分): 計算長度的單位，市制或台制，一分為一寸的十分之一。>
#   [詞性] Nf   <CwnSense[05007208](分): 計算角度的單位，一分為一度的六十分之一。>
#   [詞性] Nf   <CwnSense[05007209](分): 計算抽象事物的單位。>
# ==============================
# [a] 查詢詞義 >> 請輸入欲查詢的詞(跳出請輸入 2 )： 行
# ====================
#  [[[查詢結果]]]
#
# 所查詞彙: 行
#  詞彙(lemma)數量: 6
#  詞義(sense)數量: 25
#
# <CwnLemma: 行_1>
#   [詞性] Na   <CwnSense[05145001](行): 與行進方向或垂直方向相同的一直線。>
#   [詞性] Nf   <CwnSense[05145002](行): 計算與行進方向或垂直方向相同的一直線的單位。>
#   [詞性] Na   <CwnSense[05145003](行): 文字書寫或排版時的單位，在同一方向書寫或排版到轉變方向前為止為一行。>
#   [詞性] Nf   <CwnSense[05145004](行): 計算文字書寫或排版時的單位，在同一方向書寫或排版到轉變方向前為止為一行。>
#   [詞性] VG   <CwnSense[05145005](行): 同輩親屬依照年紀排列的次序為。>
#   [詞性] Na   <CwnSense[05145006](行): 在社會中所擔任的職務，通常為其身份認定的依據。>
#   [詞性] Nf   <CwnSense[05145007](行): 計算職業的單位。>
#   [詞性] Na   <CwnSense[05145008](行): 專門從事前述行業的商店。>
# <CwnLemma: 行_2>
#   [詞性] VA   <CwnSense[06775701](行): 以兩腿交互向前移動，雙腳不同時離開地面。>
#   [詞性] VA   <CwnSense[06775702](行): 比喻交通工具移動。>
#   [詞性] Na   <CwnSense[06775703](行): 人類社會的重要活動之ㄧ，與交通相關的一切活動。>
#   [詞性] Na   <CwnSense[06775704](行): 前往特定地點參觀或訪問的活動。>
#   [詞性] Nf   <CwnSense[06775705](行): 計算一起行動的人群的單位。>
#   [詞性] VC   <CwnSense[06775706](行): 做，取代整個事件。>
#   [詞性] VC   <CwnSense[06775707](行): 依照特定方法實際施行特定事件。>
#   [詞性] Na   <CwnSense[06775708](行): 具體表現出的外在舉止動作。>
#   [詞性] VC   <CwnSense[06775709](行): 以肢體的動作表示敬意。>
#   [詞性] VC   <CwnSense[06775710](行): 進行特定的儀式。>
#   [詞性] VH   <CwnSense[06775711](行): 形容表示同意或允許。>
#   [詞性] VH   <CwnSense[06775712](行): 形容具備完成特定事件能力的。>
#   [詞性] VH   <CwnSense[06775713](行): 形容具有令人佩服的性質的。>
# <CwnLemma: 行_3>
#   [詞性] Na   <CwnSense[06776301](行): 一種書法字體，介於楷書與草書之間，特色為筆法流暢活潑。>
# <CwnLemma: 行_4>
#   [詞性] Na   <CwnSense[06778401](行): 一種樂府和古詩的體裁。>
# <CwnLemma: 行_5>
#   [詞性] Na   <CwnSense[06778501](行): 品行。>
# <CwnLemma: 行_6>
#   [詞性] Nb   <CwnSense[06778601](行): 姓。>
# ==============================
